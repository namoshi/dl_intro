# %% [markdown]
# <a href="https://colab.research.google.com/github/namoshi/dl_intro/blob/master/CNN_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Convolutional Neural Network (CNN)
#
# Classification of handwritten numbers (MNIST) by CNN

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import torch.nn.functional as F

# %%
# load MNIST data
train_Dataset = dsets.MNIST(
      root='./data',  # rootで指定したフォルダーを作成して生データを展開
      train=True,  # 学習かテストかの選択
      transform=transforms.ToTensor(),  # PyTroch のテンソルに変換
      download=True)  # ダウンロードするかどうかの選択

test_dataset = dsets.MNIST(
      root='./data',  
      train=False, 
      transform=transforms.ToTensor(),
      download=True)

train_dataset, valid_dataset = torch.utils.data.random_split(  # データセットの分割
      train_Dataset,   # 分割するデータセット
      [10000, 50000])  # 分割数
 
print('train_dataset = ', len(train_dataset))
print('valid_dataset = ', len(valid_dataset))  
print('test_dataset = ', len(test_dataset))
# Out:
# train_dataset =  10000
# valid_dataset =  50000
# test_dataset =  10000

# %%
# set data loader
train_loader = torch.utils.data.DataLoader(
      dataset=train_dataset,  # データセットの指定
      batch_size=64,  # ミニバッチの指定
      shuffle=True,  # シャッフルするかどうかの指定
      num_workers=2)  # コアの数

valid_loader = torch.utils.data.DataLoader(
      dataset=valid_dataset,
      batch_size=64, 
      shuffle=False,
      num_workers=2)

test_loader = torch.utils.data.DataLoader(
      dataset=test_dataset,
      batch_size=64, 
      shuffle=False,
      num_workers=2)

# %%
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.conv1 = nn.Conv2d(1,32,3, padding=1)
        self.pool1 = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(32,32,3, padding=1)
        self.pool2 = nn.MaxPool2d(2,2)
        self.fc1 = nn.Linear(32*7*7, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 7 * 7)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
net = Network()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

if torch.cuda.is_available():
  net.cuda()

print('Network architecture for CNN\n', net)
# Out:
# cuda
# Network architecture for CNN
#  Network(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1568, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# ## Without Weight Decay

# %%
# optimizing with weight decay
wd = 0.00000001
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=wd)
#optimizer = optim.AdamW(net.parameters(), lr=0.01, weight_decay=0.01)

# %%
###  training
print ('training start ...')
num_epochs = 100   

# initialize list for plot graph after training
train_loss_list, train_acc_list, val_loss_list, val_acc_list = [], [], [], []

for epoch in range(num_epochs):
    # initialize each epoch
    train_loss, train_acc, val_loss, val_acc = 0, 0, 0, 0
    
    # ======== train_mode (Backprop) ======
    net.train()
    for i, (images, labels) in enumerate(train_loader):  # get mini batch samples
        #viewで28×28×１画像を１次元に変換し、deviceへ転送
#        images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()  # Reset the gradients
        outputs = net(images)  # forward computation
        loss = criterion(outputs, labels)  # loss
        loss.backward()  # backward computation        
        optimizer.step()  # optimization
    
    # ======== eval_mode (training samples) ======
    net.eval()
    with torch.no_grad():  # no computation of gradients
      for images, labels in train_loader:        
#          images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          train_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          train_acc += acc.item()
    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_acc = train_acc / len(train_loader.dataset)

    # ======== eval_mode (validation samples) ======
    net.eval()
    with torch.no_grad():  # no comptutation of gradients
      for images, labels in valid_loader:        
#          images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          val_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          val_acc += acc.item()
    avg_val_loss = val_loss / len(valid_loader.dataset)
    avg_val_acc = val_acc / len(valid_loader.dataset)
    
    # print log
    print ('Epoch [{}/{}] train Loss: {loss:.4f}, train acc: {acc:.4f} | val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}' 
                   .format(epoch+1, num_epochs, i+1, loss=avg_train_loss, acc=avg_train_acc, val_loss=avg_val_loss, val_acc=avg_val_acc))

    # append list for polt graph after training
    train_loss_list.append(avg_train_loss)
    train_acc_list.append(avg_train_acc)
    val_loss_list.append(avg_val_loss)
    val_acc_list.append(avg_val_acc)
# Out:
# training start ...
# Epoch [1/100] train Loss: 0.0357, train acc: 0.3141 | val_loss: 0.0355, val_acc: 0.3159
# Epoch [2/100] train Loss: 0.0339, train acc: 0.5206 | val_loss: 0.0338, val_acc: 0.5213
# Epoch [3/100] train Loss: 0.0197, train acc: 0.7480 | val_loss: 0.0196, val_acc: 0.7472
# Epoch [4/100] train Loss: 0.0088, train acc: 0.8273 | val_loss: 0.0088, val_acc: 0.8251
# Epoch [5/100] train Loss: 0.0067, train acc: 0.8705 | val_loss: 0.0068, val_acc: 0.8692
# Epoch [6/100] train Loss: 0.0057, train acc: 0.8866 | val_loss: 0.0059, val_acc: 0.8857
# Epoch [7/100] train Loss: 0.0054, train acc: 0.8957 | val_loss: 0.0056, val_acc: 0.8894
# Epoch [8/100] train Loss: 0.0048, train acc: 0.9059 | val_loss: 0.0051, val_acc: 0.9009
# Epoch [9/100] train Loss: 0.0049, train acc: 0.8995 | val_loss: 0.0053, val_acc: 0.8955
# Epoch [10/100] train Loss: 0.0044, train acc: 0.9111 | val_loss: 0.0048, val_acc: 0.9046
# Epoch [11/100] train Loss: 0.0038, train acc: 0.9256 | val_loss: 0.0042, val_acc: 0.9192
# Epoch [12/100] train Loss: 0.0036, train acc: 0.9282 | val_loss: 0.0040, val_acc: 0.9240
# Epoch [13/100] train Loss: 0.0032, train acc: 0.9372 | val_loss: 0.0036, val_acc: 0.9309
# Epoch [14/100] train Loss: 0.0030, train acc: 0.9404 | val_loss: 0.0035, val_acc: 0.9322
# Epoch [15/100] train Loss: 0.0031, train acc: 0.9395 | val_loss: 0.0035, val_acc: 0.9326
# Epoch [16/100] train Loss: 0.0026, train acc: 0.9459 | val_loss: 0.0032, val_acc: 0.9380
# Epoch [17/100] train Loss: 0.0026, train acc: 0.9486 | val_loss: 0.0032, val_acc: 0.9379
# Epoch [18/100] train Loss: 0.0023, train acc: 0.9534 | val_loss: 0.0029, val_acc: 0.9434
# Epoch [19/100] train Loss: 0.0025, train acc: 0.9508 | val_loss: 0.0031, val_acc: 0.9397
# Epoch [20/100] train Loss: 0.0021, train acc: 0.9559 | val_loss: 0.0028, val_acc: 0.9448
# Epoch [21/100] train Loss: 0.0021, train acc: 0.9570 | val_loss: 0.0028, val_acc: 0.9460
# Epoch [22/100] train Loss: 0.0020, train acc: 0.9594 | val_loss: 0.0027, val_acc: 0.9473
# Epoch [23/100] train Loss: 0.0018, train acc: 0.9657 | val_loss: 0.0024, val_acc: 0.9535
# Epoch [24/100] train Loss: 0.0020, train acc: 0.9615 | val_loss: 0.0027, val_acc: 0.9486
# Epoch [25/100] train Loss: 0.0016, train acc: 0.9695 | val_loss: 0.0023, val_acc: 0.9560
# Epoch [26/100] train Loss: 0.0017, train acc: 0.9667 | val_loss: 0.0024, val_acc: 0.9543
# Epoch [27/100] train Loss: 0.0016, train acc: 0.9676 | val_loss: 0.0023, val_acc: 0.9556
# Epoch [28/100] train Loss: 0.0014, train acc: 0.9739 | val_loss: 0.0022, val_acc: 0.9593
# Epoch [29/100] train Loss: 0.0014, train acc: 0.9724 | val_loss: 0.0022, val_acc: 0.9577
# Epoch [30/100] train Loss: 0.0014, train acc: 0.9717 | val_loss: 0.0023, val_acc: 0.9559
# Epoch [31/100] train Loss: 0.0013, train acc: 0.9758 | val_loss: 0.0020, val_acc: 0.9612
# Epoch [32/100] train Loss: 0.0013, train acc: 0.9730 | val_loss: 0.0021, val_acc: 0.9591
# Epoch [33/100] train Loss: 0.0013, train acc: 0.9749 | val_loss: 0.0021, val_acc: 0.9604
# Epoch [34/100] train Loss: 0.0012, train acc: 0.9727 | val_loss: 0.0021, val_acc: 0.9593
# Epoch [35/100] train Loss: 0.0011, train acc: 0.9781 | val_loss: 0.0020, val_acc: 0.9612
# Epoch [36/100] train Loss: 0.0010, train acc: 0.9795 | val_loss: 0.0019, val_acc: 0.9638
# Epoch [37/100] train Loss: 0.0010, train acc: 0.9814 | val_loss: 0.0019, val_acc: 0.9635
# Epoch [38/100] train Loss: 0.0009, train acc: 0.9826 | val_loss: 0.0018, val_acc: 0.9642
# Epoch [39/100] train Loss: 0.0009, train acc: 0.9822 | val_loss: 0.0019, val_acc: 0.9638
# Epoch [40/100] train Loss: 0.0009, train acc: 0.9845 | val_loss: 0.0018, val_acc: 0.9663
# Epoch [41/100] train Loss: 0.0009, train acc: 0.9839 | val_loss: 0.0018, val_acc: 0.9653
# Epoch [42/100] train Loss: 0.0008, train acc: 0.9846 | val_loss: 0.0018, val_acc: 0.9658
# Epoch [43/100] train Loss: 0.0008, train acc: 0.9841 | val_loss: 0.0018, val_acc: 0.9648
# Epoch [44/100] train Loss: 0.0008, train acc: 0.9851 | val_loss: 0.0017, val_acc: 0.9667
# Epoch [45/100] train Loss: 0.0007, train acc: 0.9867 | val_loss: 0.0017, val_acc: 0.9667
# Epoch [46/100] train Loss: 0.0008, train acc: 0.9833 | val_loss: 0.0019, val_acc: 0.9641
# Epoch [47/100] train Loss: 0.0007, train acc: 0.9885 | val_loss: 0.0017, val_acc: 0.9678
# Epoch [48/100] train Loss: 0.0008, train acc: 0.9853 | val_loss: 0.0018, val_acc: 0.9661
# Epoch [49/100] train Loss: 0.0007, train acc: 0.9880 | val_loss: 0.0017, val_acc: 0.9678
# Epoch [50/100] train Loss: 0.0007, train acc: 0.9895 | val_loss: 0.0017, val_acc: 0.9678
# Epoch [51/100] train Loss: 0.0006, train acc: 0.9900 | val_loss: 0.0017, val_acc: 0.9685
# Epoch [52/100] train Loss: 0.0005, train acc: 0.9909 | val_loss: 0.0017, val_acc: 0.9689
# Epoch [53/100] train Loss: 0.0006, train acc: 0.9909 | val_loss: 0.0017, val_acc: 0.9690
# Epoch [54/100] train Loss: 0.0006, train acc: 0.9902 | val_loss: 0.0017, val_acc: 0.9677
# Epoch [55/100] train Loss: 0.0005, train acc: 0.9916 | val_loss: 0.0017, val_acc: 0.9688
# Epoch [56/100] train Loss: 0.0005, train acc: 0.9917 | val_loss: 0.0016, val_acc: 0.9700
# Epoch [57/100] train Loss: 0.0005, train acc: 0.9918 | val_loss: 0.0017, val_acc: 0.9687
# Epoch [58/100] train Loss: 0.0005, train acc: 0.9925 | val_loss: 0.0016, val_acc: 0.9710
# Epoch [59/100] train Loss: 0.0004, train acc: 0.9931 | val_loss: 0.0016, val_acc: 0.9709
# Epoch [60/100] train Loss: 0.0005, train acc: 0.9917 | val_loss: 0.0016, val_acc: 0.9690
# Epoch [61/100] train Loss: 0.0004, train acc: 0.9933 | val_loss: 0.0016, val_acc: 0.9707
# Epoch [62/100] train Loss: 0.0004, train acc: 0.9948 | val_loss: 0.0016, val_acc: 0.9705
# Epoch [63/100] train Loss: 0.0004, train acc: 0.9931 | val_loss: 0.0016, val_acc: 0.9710
# Epoch [64/100] train Loss: 0.0004, train acc: 0.9928 | val_loss: 0.0016, val_acc: 0.9704
# Epoch [65/100] train Loss: 0.0004, train acc: 0.9947 | val_loss: 0.0016, val_acc: 0.9712
# Epoch [66/100] train Loss: 0.0004, train acc: 0.9946 | val_loss: 0.0016, val_acc: 0.9707
# Epoch [67/100] train Loss: 0.0004, train acc: 0.9935 | val_loss: 0.0017, val_acc: 0.9687
# Epoch [68/100] train Loss: 0.0003, train acc: 0.9953 | val_loss: 0.0016, val_acc: 0.9713
# Epoch [69/100] train Loss: 0.0003, train acc: 0.9959 | val_loss: 0.0016, val_acc: 0.9709
# Epoch [70/100] train Loss: 0.0003, train acc: 0.9956 | val_loss: 0.0016, val_acc: 0.9707
# Epoch [71/100] train Loss: 0.0003, train acc: 0.9943 | val_loss: 0.0016, val_acc: 0.9715
# Epoch [72/100] train Loss: 0.0004, train acc: 0.9937 | val_loss: 0.0017, val_acc: 0.9695
# Epoch [73/100] train Loss: 0.0003, train acc: 0.9959 | val_loss: 0.0016, val_acc: 0.9712
# Epoch [74/100] train Loss: 0.0003, train acc: 0.9968 | val_loss: 0.0016, val_acc: 0.9721
# Epoch [75/100] train Loss: 0.0003, train acc: 0.9974 | val_loss: 0.0016, val_acc: 0.9716
# Epoch [76/100] train Loss: 0.0003, train acc: 0.9939 | val_loss: 0.0017, val_acc: 0.9688
# Epoch [77/100] train Loss: 0.0003, train acc: 0.9966 | val_loss: 0.0016, val_acc: 0.9713
# Epoch [78/100] train Loss: 0.0003, train acc: 0.9943 | val_loss: 0.0018, val_acc: 0.9694
# Epoch [79/100] train Loss: 0.0003, train acc: 0.9953 | val_loss: 0.0017, val_acc: 0.9701
# Epoch [80/100] train Loss: 0.0002, train acc: 0.9978 | val_loss: 0.0016, val_acc: 0.9711
# Epoch [81/100] train Loss: 0.0002, train acc: 0.9969 | val_loss: 0.0016, val_acc: 0.9723
# Epoch [82/100] train Loss: 0.0002, train acc: 0.9974 | val_loss: 0.0016, val_acc: 0.9720
# Epoch [83/100] train Loss: 0.0002, train acc: 0.9971 | val_loss: 0.0017, val_acc: 0.9712
# Epoch [84/100] train Loss: 0.0002, train acc: 0.9973 | val_loss: 0.0017, val_acc: 0.9713
# Epoch [85/100] train Loss: 0.0002, train acc: 0.9968 | val_loss: 0.0017, val_acc: 0.9710
# Epoch [86/100] train Loss: 0.0003, train acc: 0.9949 | val_loss: 0.0017, val_acc: 0.9705
# Epoch [87/100] train Loss: 0.0002, train acc: 0.9975 | val_loss: 0.0017, val_acc: 0.9720
# Epoch [88/100] train Loss: 0.0002, train acc: 0.9983 | val_loss: 0.0016, val_acc: 0.9728
# Epoch [89/100] train Loss: 0.0002, train acc: 0.9986 | val_loss: 0.0016, val_acc: 0.9719
# Epoch [90/100] train Loss: 0.0001, train acc: 0.9992 | val_loss: 0.0016, val_acc: 0.9729
# Epoch [91/100] train Loss: 0.0002, train acc: 0.9978 | val_loss: 0.0017, val_acc: 0.9714
# Epoch [92/100] train Loss: 0.0002, train acc: 0.9986 | val_loss: 0.0017, val_acc: 0.9716
# Epoch [93/100] train Loss: 0.0002, train acc: 0.9985 | val_loss: 0.0017, val_acc: 0.9709
# Epoch [94/100] train Loss: 0.0001, train acc: 0.9990 | val_loss: 0.0017, val_acc: 0.9722
# Epoch [95/100] train Loss: 0.0001, train acc: 0.9986 | val_loss: 0.0016, val_acc: 0.9726
# Epoch [96/100] train Loss: 0.0002, train acc: 0.9974 | val_loss: 0.0017, val_acc: 0.9708
# Epoch [97/100] train Loss: 0.0002, train acc: 0.9984 | val_loss: 0.0018, val_acc: 0.9707
# Epoch [98/100] train Loss: 0.0001, train acc: 0.9995 | val_loss: 0.0017, val_acc: 0.9723
# Epoch [99/100] train Loss: 0.0001, train acc: 0.9992 | val_loss: 0.0017, val_acc: 0.9723
# Epoch [100/100] train Loss: 0.0001, train acc: 0.9995 | val_loss: 0.0016, val_acc: 0.9732

# %%
# ======== eval_mode (test samples) ======
net.eval()
with torch.no_grad():
    total = 0
    test_acc = 0
    for images, labels in test_loader:        
#        images, labels = images.view(-1, 28 * 28 * 1 ).to(device), labels.to(device)
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        test_acc += (outputs.max(1)[1] == labels).sum().item()
        total += labels.size(0)
    print('test_accuracy: {} %'.format(100 * test_acc / total)) 

# save weights (You can save the model by uncomment the following line)
#torch.save(net.state_dict(), 'mnist_net.ckpt')
# Out:
# test_accuracy: 97.57 %

# %%
# plot graph
import matplotlib.pyplot as plt

plt.figure()
plt.plot(range(num_epochs), train_loss_list, color='blue', linestyle='-', label='train_loss')
plt.plot(range(num_epochs), val_loss_list, color='green', linestyle='--', label='val_loss')
plt.ylim([0.0,0.02])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and validation loss')
plt.grid()
plt.savefig('CNN_mnist_loss_nowd.png')
plt.show()

plt.figure()
plt.plot(range(num_epochs), train_acc_list, color='blue', linestyle='-', label='train_acc')
plt.plot(range(num_epochs), val_acc_list, color='green', linestyle='--', label='val_acc')
plt.ylim([0.5, 1.0])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title('Training and validation accuracy')
plt.grid()
plt.savefig('CNN_mnist_acc_nowd.png')
plt.show()

# %% [markdown]
# # With Weight Decay

# %%
net = Network()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

if torch.cuda.is_available():
  net.cuda()

print('Network architecture for CNN\n', net)
# Out:
# cuda
# Network architecture for CNN
#  Network(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1568, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# optimizing with weight decay
wd = 0.05
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=wd)
#optimizer = optim.AdamW(net.parameters(), lr=0.01, weight_decay=0.01)

# %%
###  training
print ('training start ...')
num_epochs = 100   

# initialize list for plot graph after training
train_loss_list, train_acc_list, val_loss_list, val_acc_list = [], [], [], []

for epoch in range(num_epochs):
    # initialize each epoch
    train_loss, train_acc, val_loss, val_acc = 0, 0, 0, 0
    
    # ======== train_mode (Backprop) ======
    net.train()
    for i, (images, labels) in enumerate(train_loader):  # get mini batch samples
        #viewで28×28×１画像を１次元に変換し、deviceへ転送
#        images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()  # Reset the gradients
        outputs = net(images)  # forward computation
        loss = criterion(outputs, labels)  # loss
        loss.backward()  # backward computation        
        optimizer.step()  # optimization
    
    # ======== eval_mode (training samples) ======
    net.eval()
    with torch.no_grad():  # no computation of gradients
      for images, labels in train_loader:        
#          images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          train_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          train_acc += acc.item()
    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_acc = train_acc / len(train_loader.dataset)

    # ======== eval_mode (validation samples) ======
    net.eval()
    with torch.no_grad():  # no comptutation of gradients
      for images, labels in valid_loader:        
#          images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          val_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          val_acc += acc.item()
    avg_val_loss = val_loss / len(valid_loader.dataset)
    avg_val_acc = val_acc / len(valid_loader.dataset)
    
    # print log
    print ('Epoch [{}/{}] train Loss: {loss:.4f}, train acc: {acc:.4f} | val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}' 
                   .format(epoch+1, num_epochs, i+1, loss=avg_train_loss, acc=avg_train_acc, val_loss=avg_val_loss, val_acc=avg_val_acc))

    # append list for polt graph after training
    train_loss_list.append(avg_train_loss)
    train_acc_list.append(avg_train_acc)
    val_loss_list.append(avg_val_loss)
    val_acc_list.append(avg_val_acc)
# Out:
# training start ...
# Epoch [1/100] train Loss: 0.0355, train acc: 0.1623 | val_loss: 0.0354, val_acc: 0.1533
# Epoch [2/100] train Loss: 0.0339, train acc: 0.4299 | val_loss: 0.0338, val_acc: 0.4233
# Epoch [3/100] train Loss: 0.0235, train acc: 0.6769 | val_loss: 0.0234, val_acc: 0.6783
# Epoch [4/100] train Loss: 0.0108, train acc: 0.8165 | val_loss: 0.0107, val_acc: 0.8154
# Epoch [5/100] train Loss: 0.0084, train acc: 0.8519 | val_loss: 0.0083, val_acc: 0.8551
# Epoch [6/100] train Loss: 0.0073, train acc: 0.8732 | val_loss: 0.0073, val_acc: 0.8682
# Epoch [7/100] train Loss: 0.0066, train acc: 0.8836 | val_loss: 0.0066, val_acc: 0.8844
# Epoch [8/100] train Loss: 0.0063, train acc: 0.8905 | val_loss: 0.0064, val_acc: 0.8860
# Epoch [9/100] train Loss: 0.0062, train acc: 0.8853 | val_loss: 0.0063, val_acc: 0.8870
# Epoch [10/100] train Loss: 0.0059, train acc: 0.8938 | val_loss: 0.0060, val_acc: 0.8909
# Epoch [11/100] train Loss: 0.0061, train acc: 0.8933 | val_loss: 0.0063, val_acc: 0.8879
# Epoch [12/100] train Loss: 0.0055, train acc: 0.9030 | val_loss: 0.0057, val_acc: 0.8982
# Epoch [13/100] train Loss: 0.0055, train acc: 0.9007 | val_loss: 0.0057, val_acc: 0.8946
# Epoch [14/100] train Loss: 0.0053, train acc: 0.9055 | val_loss: 0.0055, val_acc: 0.9046
# Epoch [15/100] train Loss: 0.0051, train acc: 0.9116 | val_loss: 0.0053, val_acc: 0.9093
# Epoch [16/100] train Loss: 0.0050, train acc: 0.9101 | val_loss: 0.0052, val_acc: 0.9057
# Epoch [17/100] train Loss: 0.0049, train acc: 0.9125 | val_loss: 0.0052, val_acc: 0.9094
# Epoch [18/100] train Loss: 0.0049, train acc: 0.9097 | val_loss: 0.0052, val_acc: 0.9085
# Epoch [19/100] train Loss: 0.0050, train acc: 0.9103 | val_loss: 0.0052, val_acc: 0.9075
# Epoch [20/100] train Loss: 0.0048, train acc: 0.9156 | val_loss: 0.0051, val_acc: 0.9089
# Epoch [21/100] train Loss: 0.0047, train acc: 0.9178 | val_loss: 0.0049, val_acc: 0.9164
# Epoch [22/100] train Loss: 0.0046, train acc: 0.9183 | val_loss: 0.0049, val_acc: 0.9152
# Epoch [23/100] train Loss: 0.0048, train acc: 0.9174 | val_loss: 0.0050, val_acc: 0.9113
# Epoch [24/100] train Loss: 0.0046, train acc: 0.9244 | val_loss: 0.0048, val_acc: 0.9166
# Epoch [25/100] train Loss: 0.0044, train acc: 0.9255 | val_loss: 0.0046, val_acc: 0.9223
# Epoch [26/100] train Loss: 0.0044, train acc: 0.9245 | val_loss: 0.0046, val_acc: 0.9215
# Epoch [27/100] train Loss: 0.0045, train acc: 0.9232 | val_loss: 0.0047, val_acc: 0.9187
# Epoch [28/100] train Loss: 0.0044, train acc: 0.9270 | val_loss: 0.0046, val_acc: 0.9214
# Epoch [29/100] train Loss: 0.0045, train acc: 0.9226 | val_loss: 0.0048, val_acc: 0.9168
# Epoch [30/100] train Loss: 0.0043, train acc: 0.9290 | val_loss: 0.0046, val_acc: 0.9248
# Epoch [31/100] train Loss: 0.0043, train acc: 0.9266 | val_loss: 0.0045, val_acc: 0.9239
# Epoch [32/100] train Loss: 0.0042, train acc: 0.9292 | val_loss: 0.0044, val_acc: 0.9255
# Epoch [33/100] train Loss: 0.0042, train acc: 0.9295 | val_loss: 0.0045, val_acc: 0.9240
# Epoch [34/100] train Loss: 0.0044, train acc: 0.9256 | val_loss: 0.0047, val_acc: 0.9159
# Epoch [35/100] train Loss: 0.0042, train acc: 0.9295 | val_loss: 0.0044, val_acc: 0.9244
# Epoch [36/100] train Loss: 0.0041, train acc: 0.9305 | val_loss: 0.0044, val_acc: 0.9275
# Epoch [37/100] train Loss: 0.0041, train acc: 0.9303 | val_loss: 0.0044, val_acc: 0.9285
# Epoch [38/100] train Loss: 0.0042, train acc: 0.9299 | val_loss: 0.0045, val_acc: 0.9237
# Epoch [39/100] train Loss: 0.0040, train acc: 0.9327 | val_loss: 0.0043, val_acc: 0.9280
# Epoch [40/100] train Loss: 0.0040, train acc: 0.9344 | val_loss: 0.0042, val_acc: 0.9293
# Epoch [41/100] train Loss: 0.0041, train acc: 0.9324 | val_loss: 0.0044, val_acc: 0.9275
# Epoch [42/100] train Loss: 0.0042, train acc: 0.9315 | val_loss: 0.0044, val_acc: 0.9249
# Epoch [43/100] train Loss: 0.0041, train acc: 0.9345 | val_loss: 0.0043, val_acc: 0.9282
# Epoch [44/100] train Loss: 0.0039, train acc: 0.9349 | val_loss: 0.0042, val_acc: 0.9315
# Epoch [45/100] train Loss: 0.0040, train acc: 0.9335 | val_loss: 0.0043, val_acc: 0.9261
# Epoch [46/100] train Loss: 0.0041, train acc: 0.9295 | val_loss: 0.0044, val_acc: 0.9259
# Epoch [47/100] train Loss: 0.0041, train acc: 0.9322 | val_loss: 0.0043, val_acc: 0.9287
# Epoch [48/100] train Loss: 0.0039, train acc: 0.9362 | val_loss: 0.0042, val_acc: 0.9308
# Epoch [49/100] train Loss: 0.0040, train acc: 0.9327 | val_loss: 0.0043, val_acc: 0.9270
# Epoch [50/100] train Loss: 0.0039, train acc: 0.9374 | val_loss: 0.0041, val_acc: 0.9320
# Epoch [51/100] train Loss: 0.0040, train acc: 0.9338 | val_loss: 0.0042, val_acc: 0.9298
# Epoch [52/100] train Loss: 0.0039, train acc: 0.9370 | val_loss: 0.0041, val_acc: 0.9319
# Epoch [53/100] train Loss: 0.0039, train acc: 0.9337 | val_loss: 0.0042, val_acc: 0.9293
# Epoch [54/100] train Loss: 0.0039, train acc: 0.9346 | val_loss: 0.0042, val_acc: 0.9317
# Epoch [55/100] train Loss: 0.0041, train acc: 0.9334 | val_loss: 0.0044, val_acc: 0.9251
# Epoch [56/100] train Loss: 0.0039, train acc: 0.9364 | val_loss: 0.0041, val_acc: 0.9324
# Epoch [57/100] train Loss: 0.0041, train acc: 0.9300 | val_loss: 0.0043, val_acc: 0.9271
# Epoch [58/100] train Loss: 0.0039, train acc: 0.9345 | val_loss: 0.0041, val_acc: 0.9306
# Epoch [59/100] train Loss: 0.0038, train acc: 0.9369 | val_loss: 0.0041, val_acc: 0.9313
# Epoch [60/100] train Loss: 0.0038, train acc: 0.9376 | val_loss: 0.0041, val_acc: 0.9326
# Epoch [61/100] train Loss: 0.0038, train acc: 0.9368 | val_loss: 0.0041, val_acc: 0.9323
# Epoch [62/100] train Loss: 0.0039, train acc: 0.9356 | val_loss: 0.0041, val_acc: 0.9311
# Epoch [63/100] train Loss: 0.0039, train acc: 0.9331 | val_loss: 0.0042, val_acc: 0.9289
# Epoch [64/100] train Loss: 0.0038, train acc: 0.9381 | val_loss: 0.0040, val_acc: 0.9331
# Epoch [65/100] train Loss: 0.0038, train acc: 0.9379 | val_loss: 0.0040, val_acc: 0.9337
# Epoch [66/100] train Loss: 0.0038, train acc: 0.9370 | val_loss: 0.0040, val_acc: 0.9319
# Epoch [67/100] train Loss: 0.0039, train acc: 0.9326 | val_loss: 0.0042, val_acc: 0.9281
# Epoch [68/100] train Loss: 0.0037, train acc: 0.9395 | val_loss: 0.0040, val_acc: 0.9356
# Epoch [69/100] train Loss: 0.0039, train acc: 0.9360 | val_loss: 0.0042, val_acc: 0.9310
# Epoch [70/100] train Loss: 0.0038, train acc: 0.9383 | val_loss: 0.0041, val_acc: 0.9338
# Epoch [71/100] train Loss: 0.0038, train acc: 0.9369 | val_loss: 0.0040, val_acc: 0.9337
# Epoch [72/100] train Loss: 0.0039, train acc: 0.9378 | val_loss: 0.0042, val_acc: 0.9310
# Epoch [73/100] train Loss: 0.0039, train acc: 0.9346 | val_loss: 0.0041, val_acc: 0.9285
# Epoch [74/100] train Loss: 0.0038, train acc: 0.9387 | val_loss: 0.0041, val_acc: 0.9331
# Epoch [75/100] train Loss: 0.0039, train acc: 0.9371 | val_loss: 0.0041, val_acc: 0.9328
# Epoch [76/100] train Loss: 0.0038, train acc: 0.9365 | val_loss: 0.0041, val_acc: 0.9316
# Epoch [77/100] train Loss: 0.0040, train acc: 0.9360 | val_loss: 0.0043, val_acc: 0.9264
# Epoch [78/100] train Loss: 0.0040, train acc: 0.9349 | val_loss: 0.0042, val_acc: 0.9263
# Epoch [79/100] train Loss: 0.0038, train acc: 0.9381 | val_loss: 0.0041, val_acc: 0.9320
# Epoch [80/100] train Loss: 0.0038, train acc: 0.9388 | val_loss: 0.0040, val_acc: 0.9333
# Epoch [81/100] train Loss: 0.0038, train acc: 0.9353 | val_loss: 0.0041, val_acc: 0.9304
# Epoch [82/100] train Loss: 0.0038, train acc: 0.9373 | val_loss: 0.0041, val_acc: 0.9307
# Epoch [83/100] train Loss: 0.0038, train acc: 0.9393 | val_loss: 0.0041, val_acc: 0.9306
# Epoch [84/100] train Loss: 0.0039, train acc: 0.9349 | val_loss: 0.0042, val_acc: 0.9273
# Epoch [85/100] train Loss: 0.0038, train acc: 0.9379 | val_loss: 0.0040, val_acc: 0.9328
# Epoch [86/100] train Loss: 0.0038, train acc: 0.9389 | val_loss: 0.0041, val_acc: 0.9340
# Epoch [87/100] train Loss: 0.0037, train acc: 0.9413 | val_loss: 0.0040, val_acc: 0.9372
# Epoch [88/100] train Loss: 0.0037, train acc: 0.9394 | val_loss: 0.0040, val_acc: 0.9325
# Epoch [89/100] train Loss: 0.0038, train acc: 0.9348 | val_loss: 0.0041, val_acc: 0.9319
# Epoch [90/100] train Loss: 0.0040, train acc: 0.9316 | val_loss: 0.0042, val_acc: 0.9306
# Epoch [91/100] train Loss: 0.0038, train acc: 0.9379 | val_loss: 0.0040, val_acc: 0.9316
# Epoch [92/100] train Loss: 0.0037, train acc: 0.9382 | val_loss: 0.0040, val_acc: 0.9336
# Epoch [93/100] train Loss: 0.0038, train acc: 0.9408 | val_loss: 0.0041, val_acc: 0.9336
# Epoch [94/100] train Loss: 0.0037, train acc: 0.9409 | val_loss: 0.0039, val_acc: 0.9365
# Epoch [95/100] train Loss: 0.0037, train acc: 0.9392 | val_loss: 0.0040, val_acc: 0.9332
# Epoch [96/100] train Loss: 0.0038, train acc: 0.9359 | val_loss: 0.0040, val_acc: 0.9308
# Epoch [97/100] train Loss: 0.0037, train acc: 0.9387 | val_loss: 0.0040, val_acc: 0.9357
# Epoch [98/100] train Loss: 0.0037, train acc: 0.9409 | val_loss: 0.0039, val_acc: 0.9380
# Epoch [99/100] train Loss: 0.0037, train acc: 0.9423 | val_loss: 0.0039, val_acc: 0.9364
# Epoch [100/100] train Loss: 0.0036, train acc: 0.9409 | val_loss: 0.0039, val_acc: 0.9360

# %%
# ======== eval_mode (test samples) ======
net.eval()
with torch.no_grad():
    total = 0
    test_acc = 0
    for images, labels in test_loader:        
#        images, labels = images.view(-1, 28 * 28 * 1 ).to(device), labels.to(device)
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        test_acc += (outputs.max(1)[1] == labels).sum().item()
        total += labels.size(0)
    print('test_accuracy: {} %'.format(100 * test_acc / total)) 

# save weights (You can save the model by uncomment the following line)
#torch.save(net.state_dict(), 'mnist_net.ckpt')
# Out:
# test_accuracy: 93.98 %

# %%
# plot graph
import matplotlib.pyplot as plt

plt.figure()
plt.plot(range(num_epochs), train_loss_list, color='blue', linestyle='-', label='train_loss')
plt.plot(range(num_epochs), val_loss_list, color='green', linestyle='--', label='val_loss')
plt.ylim([0.0,0.02])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and validation loss')
plt.grid()
plt.savefig('CNN_mnist_loss_wd.png')
plt.show()

plt.figure()
plt.plot(range(num_epochs), train_acc_list, color='blue', linestyle='-', label='train_acc')
plt.plot(range(num_epochs), val_acc_list, color='green', linestyle='--', label='val_acc')
plt.ylim([0.5, 1.0])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title('Training and validation accuracy')
plt.grid()
plt.savefig('CNN_mnist_acc_wd.png')
plt.show()
