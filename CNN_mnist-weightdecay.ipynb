# %% [markdown]
# <a href="https://colab.research.google.com/github/namoshi/dl_intro/blob/master/CNN_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Convolutional Neural Network (CNN)
#
# Classification of handwritten numbers (MNIST) by CNN

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import torch.nn.functional as F

# %%
# load MNIST data
train_Dataset = dsets.MNIST(
      root='./data',  # rootで指定したフォルダーを作成して生データを展開
      train=True,  # 学習かテストかの選択
      transform=transforms.ToTensor(),  # PyTroch のテンソルに変換
      download=True)  # ダウンロードするかどうかの選択

test_dataset = dsets.MNIST(
      root='./data',  
      train=False, 
      transform=transforms.ToTensor(),
      download=True)

train_dataset, valid_dataset = torch.utils.data.random_split(  # データセットの分割
      train_Dataset,   # 分割するデータセット
      [10000, 50000])  # 分割数
 
print('train_dataset = ', len(train_dataset))
print('valid_dataset = ', len(valid_dataset))  
print('test_dataset = ', len(test_dataset))
# Out:
# train_dataset =  10000
# valid_dataset =  50000
# test_dataset =  10000

# %%
# set data loader
train_loader = torch.utils.data.DataLoader(
      dataset=train_dataset,  # データセットの指定
      batch_size=64,  # ミニバッチの指定
      shuffle=True,  # シャッフルするかどうかの指定
      num_workers=2)  # コアの数

valid_loader = torch.utils.data.DataLoader(
      dataset=valid_dataset,
      batch_size=64, 
      shuffle=False,
      num_workers=2)

test_loader = torch.utils.data.DataLoader(
      dataset=test_dataset,
      batch_size=64, 
      shuffle=False,
      num_workers=2)

# %%
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.conv1 = nn.Conv2d(1,32,3, padding=1)
        self.pool = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(32,32,3, padding=1)
        self.fc1 = nn.Linear(32*7*7, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 7 * 7)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
net = Network()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

if torch.cuda.is_available():
  net.cuda()

print('Network architecture for CNN\n', net)
# Out:
# cuda
# Network architecture for CNN
#  Network(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=1568, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# ## Without Weight Decay

# %%
# optimizing with weight decay
wd = 0.0000001
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9, weight_decay=wd)
#optimizer = optim.AdamW(net.parameters(), lr=0.01, weight_decay=0.01)

# %%
###  training
print ('training start ...')
num_epochs = 50   

# initialize list for plot graph after training
train_loss_list, train_acc_list, val_loss_list, val_acc_list = [], [], [], []

for epoch in range(num_epochs):
    # initialize each epoch
    train_loss, train_acc, val_loss, val_acc = 0, 0, 0, 0
    
    # ======== train_mode (Backprop) ======
    net.train()
    for i, (images, labels) in enumerate(train_loader):  # get mini batch samples
        #viewで28×28×１画像を１次元に変換し、deviceへ転送
#        images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()  # Reset the gradients
        outputs = net(images)  # forward computation
        loss = criterion(outputs, labels)  # loss
        loss.backward()  # backward computation        
        optimizer.step()  # optimization
    
    # ======== eval_mode (training samples) ======
    net.eval()
    with torch.no_grad():  # no computation of gradients
      for images, labels in train_loader:        
#          images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          train_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          train_acc += acc.item()
    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_acc = train_acc / len(train_loader.dataset)

    # ======== eval_mode (validation samples) ======
    net.eval()
    with torch.no_grad():  # no comptutation of gradients
      for images, labels in valid_loader:        
#          images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          val_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          val_acc += acc.item()
    avg_val_loss = val_loss / len(valid_loader.dataset)
    avg_val_acc = val_acc / len(valid_loader.dataset)
    
    # print log
    print ('Epoch [{}/{}] train Loss: {loss:.4f}, train acc: {acc:.4f} | val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}' 
                   .format(epoch+1, num_epochs, i+1, loss=avg_train_loss, acc=avg_train_acc, val_loss=avg_val_loss, val_acc=avg_val_acc))

    # append list for polt graph after training
    train_loss_list.append(avg_train_loss)
    train_acc_list.append(avg_train_acc)
    val_loss_list.append(avg_val_loss)
    val_acc_list.append(avg_val_acc)
# Out:
# training start ...
# Epoch [1/50] train Loss: 0.0065, train acc: 0.8695 | val_loss: 0.0064, val_acc: 0.8741
# Epoch [2/50] train Loss: 0.0034, train acc: 0.9330 | val_loss: 0.0035, val_acc: 0.9305
# Epoch [3/50] train Loss: 0.0020, train acc: 0.9622 | val_loss: 0.0022, val_acc: 0.9563
# Epoch [4/50] train Loss: 0.0017, train acc: 0.9666 | val_loss: 0.0021, val_acc: 0.9585
# Epoch [5/50] train Loss: 0.0012, train acc: 0.9785 | val_loss: 0.0017, val_acc: 0.9658
# Epoch [6/50] train Loss: 0.0011, train acc: 0.9786 | val_loss: 0.0018, val_acc: 0.9656
# Epoch [7/50] train Loss: 0.0008, train acc: 0.9842 | val_loss: 0.0015, val_acc: 0.9709
# Epoch [8/50] train Loss: 0.0006, train acc: 0.9883 | val_loss: 0.0014, val_acc: 0.9735
# Epoch [9/50] train Loss: 0.0005, train acc: 0.9910 | val_loss: 0.0013, val_acc: 0.9743
# Epoch [10/50] train Loss: 0.0004, train acc: 0.9915 | val_loss: 0.0013, val_acc: 0.9757
# Epoch [11/50] train Loss: 0.0005, train acc: 0.9905 | val_loss: 0.0014, val_acc: 0.9745
# Epoch [12/50] train Loss: 0.0003, train acc: 0.9938 | val_loss: 0.0013, val_acc: 0.9762
# Epoch [13/50] train Loss: 0.0003, train acc: 0.9952 | val_loss: 0.0013, val_acc: 0.9750
# Epoch [14/50] train Loss: 0.0002, train acc: 0.9968 | val_loss: 0.0014, val_acc: 0.9764
# Epoch [15/50] train Loss: 0.0001, train acc: 0.9986 | val_loss: 0.0013, val_acc: 0.9780
# Epoch [16/50] train Loss: 0.0001, train acc: 0.9982 | val_loss: 0.0014, val_acc: 0.9766
# Epoch [17/50] train Loss: 0.0001, train acc: 0.9985 | val_loss: 0.0013, val_acc: 0.9785
# Epoch [18/50] train Loss: 0.0001, train acc: 0.9980 | val_loss: 0.0014, val_acc: 0.9763
# Epoch [19/50] train Loss: 0.0001, train acc: 0.9991 | val_loss: 0.0014, val_acc: 0.9769
# Epoch [20/50] train Loss: 0.0000, train acc: 0.9999 | val_loss: 0.0014, val_acc: 0.9789
# Epoch [21/50] train Loss: 0.0001, train acc: 0.9990 | val_loss: 0.0015, val_acc: 0.9778
# Epoch [22/50] train Loss: 0.0000, train acc: 0.9997 | val_loss: 0.0015, val_acc: 0.9785
# Epoch [23/50] train Loss: 0.0000, train acc: 0.9999 | val_loss: 0.0014, val_acc: 0.9780
# Epoch [24/50] train Loss: 0.0000, train acc: 0.9999 | val_loss: 0.0014, val_acc: 0.9793
# Epoch [25/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0014, val_acc: 0.9797
# Epoch [26/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0014, val_acc: 0.9794
# Epoch [27/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0014, val_acc: 0.9797
# Epoch [28/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0015, val_acc: 0.9795
# Epoch [29/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0015, val_acc: 0.9797
# Epoch [30/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0015, val_acc: 0.9796
# Epoch [31/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0015, val_acc: 0.9795
# Epoch [32/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0015, val_acc: 0.9799
# Epoch [33/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0015, val_acc: 0.9798
# Epoch [34/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0015, val_acc: 0.9797
# Epoch [35/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0015, val_acc: 0.9800
# Epoch [36/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9799
# Epoch [37/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9795
# Epoch [38/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9797
# Epoch [39/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9800
# Epoch [40/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9797
# Epoch [41/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9799
# Epoch [42/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9799
# Epoch [43/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9798
# Epoch [44/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9795
# Epoch [45/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9795
# Epoch [46/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9795
# Epoch [47/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9800
# Epoch [48/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0016, val_acc: 0.9797
# Epoch [49/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0017, val_acc: 0.9797
# Epoch [50/50] train Loss: 0.0000, train acc: 1.0000 | val_loss: 0.0017, val_acc: 0.9799

# %%
# ======== eval_mode (test samples) ======
net.eval()
with torch.no_grad():
    total = 0
    test_acc = 0
    for images, labels in test_loader:        
#        images, labels = images.view(-1, 28 * 28 * 1 ).to(device), labels.to(device)
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        test_acc += (outputs.max(1)[1] == labels).sum().item()
        total += labels.size(0)
    print('test_accuracy: {} %'.format(100 * test_acc / total)) 

# save weights (You can save the model by uncomment the following line)
#torch.save(net.state_dict(), 'mnist_net.ckpt')
# Out:
# test_accuracy: 98.22 %

# %%
# plot graph
import matplotlib.pyplot as plt

plt.figure()
plt.plot(range(num_epochs), train_loss_list, color='blue', linestyle='-', label='train_loss')
plt.plot(range(num_epochs), val_loss_list, color='green', linestyle='--', label='val_loss')
plt.ylim([0.0,0.02])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and validation loss')
plt.grid()
plt.savefig('CNN_mnist_loss_nowd.png')
plt.show()

plt.figure()
plt.plot(range(num_epochs), train_acc_list, color='blue', linestyle='-', label='train_acc')
plt.plot(range(num_epochs), val_acc_list, color='green', linestyle='--', label='val_acc')
plt.ylim([0.5, 1.0])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title('Training and validation accuracy')
plt.grid()
plt.savefig('CNN_mnist_acc_nowd.png')
plt.show()

# %% [markdown]
# # With Weight Decay

# %%
net = Network()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

if torch.cuda.is_available():
  net.cuda()

print('Network architecture for CNN\n', net)
# Out:
# cuda
# Network architecture for CNN
#  Network(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=1568, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# optimizing with weight decay
wd = 0.001
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9, weight_decay=wd)
#optimizer = optim.AdamW(net.parameters(), lr=0.01, weight_decay=0.01)

# %%
###  training
print ('training start ...')
num_epochs = 50   

# initialize list for plot graph after training
train_loss_list, train_acc_list, val_loss_list, val_acc_list = [], [], [], []

for epoch in range(num_epochs):
    # initialize each epoch
    train_loss, train_acc, val_loss, val_acc = 0, 0, 0, 0
    
    # ======== train_mode (Backprop) ======
    net.train()
    for i, (images, labels) in enumerate(train_loader):  # get mini batch samples
        #viewで28×28×１画像を１次元に変換し、deviceへ転送
#        images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()  # Reset the gradients
        outputs = net(images)  # forward computation
        loss = criterion(outputs, labels)  # loss
        loss.backward()  # backward computation        
        optimizer.step()  # optimization
    
    # ======== eval_mode (training samples) ======
    net.eval()
    with torch.no_grad():  # no computation of gradients
      for images, labels in train_loader:        
#          images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          train_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          train_acc += acc.item()
    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_acc = train_acc / len(train_loader.dataset)

    # ======== eval_mode (validation samples) ======
    net.eval()
    with torch.no_grad():  # no comptutation of gradients
      for images, labels in valid_loader:        
#          images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          val_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          val_acc += acc.item()
    avg_val_loss = val_loss / len(valid_loader.dataset)
    avg_val_acc = val_acc / len(valid_loader.dataset)
    
    # print log
    print ('Epoch [{}/{}] train Loss: {loss:.4f}, train acc: {acc:.4f} | val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}' 
                   .format(epoch+1, num_epochs, i+1, loss=avg_train_loss, acc=avg_train_acc, val_loss=avg_val_loss, val_acc=avg_val_acc))

    # append list for polt graph after training
    train_loss_list.append(avg_train_loss)
    train_acc_list.append(avg_train_acc)
    val_loss_list.append(avg_val_loss)
    val_acc_list.append(avg_val_acc)
# Epoch [30/50] train Loss: 0.0001, train acc: 1.0000 | val_loss: 0.0011, val_acc: 0.9805
# Epoch [31/50] train Loss: 0.0001, train acc: 0.9999 | val_loss: 0.0010, val_acc: 0.9811
# Epoch [32/50] train Loss: 0.0001, train acc: 0.9999 | val_loss: 0.0010, val_acc: 0.9808
# Epoch [33/50] train Loss: 0.0001, train acc: 0.9999 | val_loss: 0.0011, val_acc: 0.9809
# Epoch [34/50] train Loss: 0.0001, train acc: 0.9999 | val_loss: 0.0010, val_acc: 0.9811
# Epoch [35/50] train Loss: 0.0001, train acc: 1.0000 | val_loss: 0.0011, val_acc: 0.9806
# Epoch [36/50] train Loss: 0.0001, train acc: 0.9998 | val_loss: 0.0011, val_acc: 0.9812
# Epoch [37/50] train Loss: 0.0002, train acc: 0.9976 | val_loss: 0.0013, val_acc: 0.9769
# Epoch [38/50] train Loss: 0.0001, train acc: 0.9994 | val_loss: 0.0011, val_acc: 0.9792
# Epoch [39/50] train Loss: 0.0001, train acc: 0.9999 | val_loss: 0.0011, val_acc: 0.9797
# Epoch [40/50] train Loss: 0.0001, train acc: 0.9997 | val_loss: 0.0011, val_acc: 0.9796
# Epoch [41/50] train Loss: 0.0001, train acc: 1.0000 | val_loss: 0.0011, val_acc: 0.9796
# Epoch [42/50] train Loss: 0.0001, train acc: 0.9990 | val_loss: 0.0013, val_acc: 0.9773
# Epoch [43/50] train Loss: 0.0001, train acc: 0.9994 | val_loss: 0.0011, val_acc: 0.9798
# Epoch [44/50] train Loss: 0.0001, train acc: 0.9997 | val_loss: 0.0012, val_acc: 0.9786
# Epoch [45/50] train Loss: 0.0001, train acc: 0.9998 | val_loss: 0.0011, val_acc: 0.9800
# Epoch [46/50] train Loss: 0.0001, train acc: 1.0000 | val_loss: 0.0010, val_acc: 0.9810
# Epoch [47/50] train Loss: 0.0001, train acc: 1.0000 | val_loss: 0.0011, val_acc: 0.9811
# Epoch [48/50] train Loss: 0.0001, train acc: 0.9999 | val_loss: 0.0010, val_acc: 0.9813
# Epoch [49/50] train Loss: 0.0001, train acc: 1.0000 | val_loss: 0.0011, val_acc: 0.9795
# Epoch [50/50] train Loss: 0.0001, train acc: 1.0000 | val_loss: 0.0010, val_acc: 0.9804

# %%
# ======== eval_mode (test samples) ======
net.eval()
with torch.no_grad():
    total = 0
    test_acc = 0
    for images, labels in test_loader:        
#        images, labels = images.view(-1, 28 * 28 * 1 ).to(device), labels.to(device)
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        test_acc += (outputs.max(1)[1] == labels).sum().item()
        total += labels.size(0)
    print('test_accuracy: {} %'.format(100 * test_acc / total)) 

# save weights (You can save the model by uncomment the following line)
#torch.save(net.state_dict(), 'mnist_net.ckpt')
# Out:
# test_accuracy: 96.88 %

# %%
# plot graph
import matplotlib.pyplot as plt

plt.figure()
plt.plot(range(num_epochs), train_loss_list, color='blue', linestyle='-', label='train_loss')
plt.plot(range(num_epochs), val_loss_list, color='green', linestyle='--', label='val_loss')
plt.ylim([0.0,0.02])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and validation loss')
plt.grid()
plt.savefig('CNN_mnist_loss_wd.png')
plt.show()

plt.figure()
plt.plot(range(num_epochs), train_acc_list, color='blue', linestyle='-', label='train_acc')
plt.plot(range(num_epochs), val_acc_list, color='green', linestyle='--', label='val_acc')
plt.ylim([0.5, 1.0])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title('Training and validation accuracy')
plt.grid()
plt.savefig('CNN_mnist_acc_wd.png')
plt.show()
